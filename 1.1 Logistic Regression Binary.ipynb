# %% [markdown]
# # 0. Import Packages

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

from sklearn.decomposition import PCA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

# %%
from imblearn.over_sampling import SMOTE

# %%
from scipy.stats import chi2_contingency, pointbiserialr

# %% [markdown]
# # 1. Load Dataset

# %%
# Load cancer dataset
cancer = load_breast_cancer()
cancer_df = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)

# Target variable to the DataFrame
cancer_df['target'] = cancer.target

print("Shape of The Dataset : ", cancer_df.shape)
cancer_df.head(3)
# Out:
# Shape of The Dataset :  (569, 31)
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  radius error  texture error  perimeter error  \
# 0                 0.07871        1.0950         0.9053            8.589
# 1                 0.05667        0.5435         0.7339            3.398
# 2                 0.05999        0.7456         0.7869            4.585
#
#    area error  smoothness error  compactness error  concavity error  \
# 0      153.40          0.006399            0.04904          0.05373
# 1       74.08          0.005225            0.01308          0.01860
# 2       94.03          0.006150            0.04006          0.03832
#
#    concave points error  symmetry error  fractal dimension error  \
# 0               0.01587         0.03003                 0.006193
# 1               0.01340         0.01389                 0.003532
# 2               0.02058         0.02250                 0.004571
#
#    worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0         25.38          17.33            184.6      2019.0            0.1622
# 1         24.99          23.41            158.8      1956.0            0.1238
# 2         23.57          25.53            152.5      1709.0            0.1444
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
#
#    worst fractal dimension  target
# 0                  0.11890       0
# 1                  0.08902       0
# 2                  0.08758       0

# %% [markdown]
# # 2. The Split

# %%
# Split data into training and testing sets
train, test = train_test_split(cancer_df, test_size=0.3, random_state=99)

print("Training data shape:", train.shape)
print("Testing data shape:", test.shape)
# Out:
# Training data shape: (398, 31)
# Testing data shape: (171, 31)

# %% [markdown]
# # 3. Data Exploration

# %% [markdown]
# ## 3.1 Target Split & Balance

# %%
train["target"].value_counts()
# Out:
# target
# 1    244
# 0    154
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state=99)
X_train, y_train = smote.fit_resample(train.drop("target", axis=1), train["target"])
y_train.value_counts()
# Out:
# target
# 1    244
# 0    244
# Name: count, dtype: int64

# %% [markdown]
# ## 3.2 Null Value Analysis

# %%
X_train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# No Analysis Required

# %% [markdown]
# ## 3.3 Important Features & P-Value

# %%
def point_biserial_coeff(df, binary_cat, continuous_cat):
        '''
        Measures the correlation between a continuous variable and a binary variable.
        Appropriate when one variable is continuous and the other is dichotomous (binary).
        Ranges from -1 to 1, where -1 indicates a perfect negative correlation, 1 indicates a perfect positive correlation, and 0 indicates no correlation.
        Interpreted similar to Pearson correlation coefficient (i.e., strength and direction of linear relationship).
        '''
        point_biserial_corr, p_value = pointbiserialr(df[binary_cat], df[continuous_cat])
        return point_biserial_corr, p_value

# %%
association_mat = []
for feature in train.columns:
    if feature != 'target' and feature != 'label':
        # print(feature, ' : ')
        corr, p_value = point_biserial_coeff(train, 'target', feature)
        association_mat.append([feature, corr, p_value])


association_pd = pd.DataFrame(association_mat, columns=["Feature","Point-Biserial Coef.", "P-value"])
association_pd.sort_values(by = "P-value")
# Out:
#                     Feature  Point-Biserial Coef.       P-value
# 27     worst concave points             -0.790124  3.340373e-86
# 22          worst perimeter             -0.780101  1.143069e-82
# 20             worst radius             -0.772451  4.292594e-80
# 7       mean concave points             -0.769577  3.750747e-79
# 2            mean perimeter             -0.740620  2.245303e-70
# 0               mean radius             -0.728663  4.372977e-67
# 23               worst area             -0.727402  9.493605e-67
# 3                 mean area             -0.708006  8.485544e-62
# 6            mean concavity             -0.690650  1.062156e-57
# 26          worst concavity             -0.643659  6.206875e-48
# 25        worst compactness             -0.583908  9.558922e-38
# 5          mean compactness             -0.572794  4.465612e-36
# 10             radius error             -0.565362  5.384831e-35
# 12          perimeter error             -0.549968  7.693905e-33
# 13               area error             -0.528516  5.115756e-30
# 21            worst texture             -0.446077  7.412544e-21
# 17     concave points error             -0.435628  7.301696e-20
# 24         worst smoothness             -0.409938  1.459471e-17
# 28           worst symmetry             -0.405277  3.637859e-17
# 1              mean texture             -0.398657  1.299013e-16
# 4           mean smoothness             -0.328440  1.829150e-11
# 8             mean symmetry             -0.316129  1.095531e-10
# 29  worst fractal dimension             -0.312654  1.789310e-10
# 15        compactness error             -0.290309  3.613339e-09
# 16          concavity error             -0.273591  2.903853e-08
# 19  fractal dimension error             -0.089010  7.611508e-02
# 14         smoothness error              0.054549  2.776449e-01
# 9    mean fractal dimension              0.040748  4.175411e-01
# 18           symmetry error              0.011225  8.233410e-01
# 11            texture error              0.009837  8.448940e-01

# %% [markdown]
# Other than, "texture_error", "symmetry_error" and "mean fractal error" other columns are significant.

# %%
train_log = np.log(train.drop('target', axis=1) + 1)  # Adding 1 to avoid log(0) if any value is 0
train_log["target"] =  train["target"]
train_log.describe()
# Out:
#        mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# count   398.000000    398.000000      398.000000  398.000000       398.000000
# mean      2.700225      2.985248        4.510703    6.384107         0.092348
# std       0.224870      0.211701        0.250657    0.488315         0.013250
# min       2.077064      2.431857        3.801985    4.973280         0.062308
# 25%       2.542389      2.842144        4.334803    6.043464         0.082927
# 50%       2.673459      2.977313        4.481306    6.327311         0.092055
# 75%       2.848102      3.122145        4.681900    6.706493         0.100818
# max       3.371082      3.695855        5.244389    7.824846         0.151347
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# count        398.000000      398.000000           398.000000     398.000000
# mean           0.099519        0.083982             0.048135       0.166619
# std            0.046757        0.069054             0.036142       0.023316
# min            0.023170        0.000000             0.000000       0.110378
# 25%            0.064865        0.029646             0.020533       0.150358
# 50%            0.091521        0.065095             0.036559       0.165430
# 75%            0.122726        0.126170             0.072941       0.178397
# max            0.296691        0.355434             0.183321       0.265436
#
#        mean fractal dimension  radius error  texture error  perimeter error  \
# count              398.000000    398.000000     398.000000       398.000000
# mean                 0.060999      0.330601       0.764605         1.272084
# std                  0.006707      0.172584       0.230515         0.406253
# min                  0.048752      0.105710       0.307632         0.563608
# 25%                  0.056113      0.210605       0.600209         0.958391
# 50%                  0.059810      0.287845       0.725372         1.202058
# 75%                  0.064296      0.402333       0.906139         1.476417
# max                  0.091439      1.354029       1.772407         3.134624
#
#        area error  smoothness error  compactness error  concavity error  \
# count  398.000000        398.000000         398.000000       398.000000
# mean     3.445645          0.007067           0.025192         0.031188
# std      0.726889          0.003104           0.016867         0.025670
# min      2.107543          0.001712           0.003007         0.000000
# 25%      2.939155          0.005222           0.012785         0.015851
# 50%      3.246491          0.006342           0.020694         0.025931
# 75%      3.871346          0.008166           0.032837         0.040799
# max      6.297478          0.030655           0.101112         0.265283
#
#        concave points error  symmetry error  fractal dimension error  \
# count            398.000000      398.000000               398.000000
# mean               0.011771        0.020677                 0.003805
# std                0.005756        0.008460                 0.002454
# min                0.000000        0.007851                 0.000894
# 25%                0.007978        0.015051                 0.002235
# 50%                0.011251        0.018851                 0.003211
# 75%                0.014832        0.023384                 0.004549
# max                0.040086        0.075988                 0.022603
#
#        worst radius  worst texture  worst perimeter  worst area  \
# count    398.000000     398.000000       398.000000  398.000000
# mean       2.822912       3.251321         4.650940    6.636414
# std        0.265644       0.235086         0.293085    0.565601
# min        2.189416       2.601949         3.939833    5.226821
# 25%        2.642800       3.083285         4.445294    6.248091
# 50%        2.773838       3.260401         4.594615    6.542884
# 75%        3.013324       3.421733         4.863101    7.052937
# max        3.611998       3.874529         5.530222    8.355850
#
#        worst smoothness  worst compactness  worst concavity  \
# count        398.000000         398.000000       398.000000
# mean           0.124586           0.221193         0.231054
# std            0.020910           0.118180         0.154613
# min            0.068752           0.026924         0.000000
# 25%            0.110020           0.137782         0.113530
# 50%            0.123588           0.196019         0.208314
# 75%            0.138043           0.293863         0.328332
# max            0.200980           0.721735         0.811819
#
#        worst concave points  worst symmetry  worst fractal dimension  \
# count            398.000000      398.000000               398.000000
# mean               0.108150        0.254511                 0.080729
# std                0.058669        0.047834                 0.016831
# min                0.000000        0.145398                 0.053579
# 25%                0.061596        0.223703                 0.068817
# 50%                0.097081        0.248148                 0.077044
# 75%                0.153386        0.277329                 0.088196
# max                0.255417        0.455778                 0.188552
#
#            target
# count  398.000000
# mean     0.613065
# std      0.487662
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
association_mat = []
for feature in train.columns:
    if feature != 'target' and feature != 'label':
        # print(feature, ' : ')
        corr, p_value = point_biserial_coeff(train, 'target', feature)
        association_mat.append([feature, corr, p_value])


association_pd = pd.DataFrame(association_mat, columns=["Feature","Point-Biserial Coef.", "P-value"])
association_pd.sort_values(by = "P-value")
